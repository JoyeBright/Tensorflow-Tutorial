# %% [markdown]
# <a href="https://colab.research.google.com/github/JoyeBright/Tensorflow-Tutorial/blob/master/Flowers_with_CNN_DataAugmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Goal: To classify images of flowers.

# %% [markdown]
# ## **Importing**

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## **Data importing**

# %%
URL = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

# %%
zip_file = tf.keras.utils.get_file(origin=URL,
                                   fname="flower_photos.tgz",
                                   extract=True)

base_dir = os.path.join(os.path.dirname(zip_file), 'flower_photos')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 2s 0us/step

# %% [markdown]
# ## **Dataset classes**

# %%
classes = ['roses', 'daisy', 'dandelion', 'sunflowers', 'tulips']

# %% [markdown]
# ## **Dataset training and validation data**

# %%
import glob
import shutil

# %%
for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  print("{}: {} Images".format(cl, len(images)))
  num_train = int(round(len(images)*0.8))
  train, val = images[:num_train], images[num_train:]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))
# Out:
# roses: 641 Images
# daisy: 633 Images
# dandelion: 898 Images
# sunflowers: 699 Images
# tulips: 799 Images

# %%
round(len(images)*0.8)
# Out:
# 639

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

# %% [markdown]
# ## **Data augmentation**

# %%
batch_size = 100
IMG_SHAPE = 150

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## **DA: Random horizontal flip**

# %%
image_gen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)

train_data_gen = image_gen.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE)
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %%
import matplotlib.pyplot as plt

# %%
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(15, 15))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()


augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ## **DA: Random rotation**

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range=45)

train_data_gen = image_gen.flow_from_directory(batch_size=batch_size,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ## **DA: Apply zoom**

# %%
image_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.5)

train_data_gen = image_gen.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE, IMG_SHAPE)
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ## **DA: All togeter**

# %%
image_gen_train = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )


train_data_gen = image_gen_train.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='sparse'
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### **Create a Data Generator for the Validation Set**

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size,
                                                 directory=val_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='sparse')
# Out:
# Found 735 images belonging to 5 classes.

# %% [markdown]
# ## **CNN model structure**

# %%
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_SHAPE,IMG_SHAPE, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(5))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 80

history = model.fit(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(batch_size))),
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(batch_size)))
)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 22s 733ms/step - loss: 1.5341 - accuracy: 0.3445 - val_loss: 1.2674 - val_accuracy: 0.4585
# Epoch 2/80
# 30/30 [==============================] - 22s 744ms/step - loss: 1.2135 - accuracy: 0.4899 - val_loss: 1.1579 - val_accuracy: 0.5361
# Epoch 3/80
# 30/30 [==============================] - 23s 776ms/step - loss: 1.1064 - accuracy: 0.5578 - val_loss: 1.0460 - val_accuracy: 0.6054
# Epoch 4/80
# 30/30 [==============================] - 23s 754ms/step - loss: 1.0476 - accuracy: 0.5727 - val_loss: 1.0038 - val_accuracy: 0.5986
# Epoch 5/80
# 30/30 [==============================] - 23s 758ms/step - loss: 0.9727 - accuracy: 0.6170 - val_loss: 1.0032 - val_accuracy: 0.6136
# Epoch 6/80
# 30/30 [==============================] - 23s 752ms/step - loss: 0.9469 - accuracy: 0.6228 - val_loss: 0.8755 - val_accuracy: 0.6503
# Epoch 7/80
# 30/30 [==============================] - 22s 742ms/step - loss: 0.9332 - accuracy: 0.6269 - val_loss: 0.8895 - val_accuracy: 0.6585
# Epoch 8/80
# 30/30 [==============================] - 22s 747ms/step - loss: 0.8879 - accuracy: 0.6532 - val_loss: 0.7799 - val_accuracy: 0.7088
# Epoch 9/80
# 30/30 [==============================] - 23s 758ms/step - loss: 0.8736 - accuracy: 0.6508 - val_loss: 0.8222 - val_accuracy: 0.6803
# Epoch 10/80
# 30/30 [==============================] - 23s 754ms/step - loss: 0.8688 - accuracy: 0.6617 - val_loss: 0.8117 - val_accuracy: 0.6898
# Epoch 11/80
# 30/30 [==============================] - 23s 750ms/step - loss: 0.8398 - accuracy: 0.6709 - val_loss: 0.9238 - val_accuracy: 0.6449
# Epoch 12/80
# 30/30 [==============================] - 22s 748ms/step - loss: 0.8222 - accuracy: 0.6763 - val_loss: 0.7904 - val_accuracy: 0.6803
# Epoch 13/80
# 30/30 [==============================] - 23s 755ms/step - loss: 0.8383 - accuracy: 0.6743 - val_loss: 0.7832 - val_accuracy: 0.6925
# Epoch 14/80
# 30/30 [==============================] - 23s 754ms/step - loss: 0.8089 - accuracy: 0.6770 - val_loss: 0.7539 - val_accuracy: 0.7048
# Epoch 15/80
# 30/30 [==============================] - 22s 748ms/step - loss: 0.7956 - accuracy: 0.6882 - val_loss: 0.7542 - val_accuracy: 0.7184
# Epoch 16/80
# 30/30 [==============================] - 23s 756ms/step - loss: 0.7849 - accuracy: 0.6906 - val_loss: 0.7117 - val_accuracy: 0.7293
# Epoch 17/80
# 30/30 [==============================] - 23s 756ms/step - loss: 0.7882 - accuracy: 0.6944 - val_loss: 0.6891 - val_accuracy: 0.7252
# Epoch 18/80
# 30/30 [==============================] - 22s 749ms/step - loss: 0.7517 - accuracy: 0.7080 - val_loss: 0.7312 - val_accuracy: 0.7211
# Epoch 19/80
# 30/30 [==============================] - 22s 746ms/step - loss: 0.7523 - accuracy: 0.7066 - val_loss: 0.6392 - val_accuracy: 0.7687
# Epoch 20/80
# 30/30 [==============================] - 23s 751ms/step - loss: 0.7491 - accuracy: 0.7046 - val_loss: 0.6706 - val_accuracy: 0.7333
# Epoch 21/80
# 30/30 [==============================] - 22s 740ms/step - loss: 0.7166 - accuracy: 0.7189 - val_loss: 0.7087 - val_accuracy: 0.7224
# Epoch 22/80
# 30/30 [==============================] - 22s 738ms/step - loss: 0.7192 - accuracy: 0.7254 - val_loss: 0.6620 - val_accuracy: 0.7347
# Epoch 23/80
# 30/30 [==============================] - 22s 736ms/step - loss: 0.7384 - accuracy: 0.7060 - val_loss: 0.7076 - val_accuracy: 0.7170
# Epoch 24/80
# 30/30 [==============================] - 22s 737ms/step - loss: 0.6880 - accuracy: 0.7349 - val_loss: 0.6173 - val_accuracy: 0.7551
# Epoch 25/80
# 30/30 [==============================] - 22s 739ms/step - loss: 0.6862 - accuracy: 0.7339 - val_loss: 0.6524 - val_accuracy: 0.7429
# Epoch 26/80
# 30/30 [==============================] - 22s 740ms/step - loss: 0.6990 - accuracy: 0.7339 - val_loss: 0.6665 - val_accuracy: 0.7252
# Epoch 27/80
# 30/30 [==============================] - 23s 762ms/step - loss: 0.6870 - accuracy: 0.7298 - val_loss: 0.7049 - val_accuracy: 0.7238
# Epoch 28/80
# 30/30 [==============================] - 22s 741ms/step - loss: 0.6594 - accuracy: 0.7424 - val_loss: 0.6934 - val_accuracy: 0.7211
# Epoch 29/80
# 30/30 [==============================] - 22s 750ms/step - loss: 0.6436 - accuracy: 0.7414 - val_loss: 0.6524 - val_accuracy: 0.7483
# Epoch 30/80
# 30/30 [==============================] - 23s 760ms/step - loss: 0.6325 - accuracy: 0.7455 - val_loss: 0.6131 - val_accuracy: 0.7646
# Epoch 31/80
# 30/30 [==============================] - 22s 750ms/step - loss: 0.6329 - accuracy: 0.7523 - val_loss: 0.6616 - val_accuracy: 0.7510
# Epoch 32/80
# 30/30 [==============================] - 22s 746ms/step - loss: 0.6230 - accuracy: 0.7526 - val_loss: 0.6093 - val_accuracy: 0.7524
# Epoch 33/80
# 30/30 [==============================] - 22s 747ms/step - loss: 0.6458 - accuracy: 0.7489 - val_loss: 0.6017 - val_accuracy: 0.7660
# Epoch 34/80
# 30/30 [==============================] - 23s 757ms/step - loss: 0.6404 - accuracy: 0.7656 - val_loss: 0.6122 - val_accuracy: 0.7388
# Epoch 35/80
# 30/30 [==============================] - 23s 753ms/step - loss: 0.5974 - accuracy: 0.7639 - val_loss: 0.7045 - val_accuracy: 0.7469
# Epoch 36/80
# 30/30 [==============================] - 23s 752ms/step - loss: 0.5934 - accuracy: 0.7693 - val_loss: 0.6799 - val_accuracy: 0.7510
# Epoch 37/80
# 30/30 [==============================] - 23s 755ms/step - loss: 0.6238 - accuracy: 0.7588 - val_loss: 0.5809 - val_accuracy: 0.7755
# Epoch 38/80
# 30/30 [==============================] - 23s 753ms/step - loss: 0.5840 - accuracy: 0.7717 - val_loss: 0.6173 - val_accuracy: 0.7633
# Epoch 39/80
# 30/30 [==============================] - 22s 745ms/step - loss: 0.5914 - accuracy: 0.7744 - val_loss: 0.6340 - val_accuracy: 0.7537
# Epoch 40/80
# 30/30 [==============================] - 22s 748ms/step - loss: 0.5946 - accuracy: 0.7642 - val_loss: 0.6173 - val_accuracy: 0.7605
# Epoch 41/80
# 30/30 [==============================] - 22s 750ms/step - loss: 0.5716 - accuracy: 0.7727 - val_loss: 0.6203 - val_accuracy: 0.7619
# Epoch 42/80
# 30/30 [==============================] - 22s 743ms/step - loss: 0.5813 - accuracy: 0.7758 - val_loss: 0.5760 - val_accuracy: 0.7646
# Epoch 43/80
# 30/30 [==============================] - 23s 753ms/step - loss: 0.5740 - accuracy: 0.7755 - val_loss: 0.5906 - val_accuracy: 0.7592
# Epoch 44/80
# 30/30 [==============================] - 22s 750ms/step - loss: 0.5759 - accuracy: 0.7710 - val_loss: 0.5991 - val_accuracy: 0.7714
# Epoch 45/80
# 30/30 [==============================] - 22s 748ms/step - loss: 0.5736 - accuracy: 0.7785 - val_loss: 0.5732 - val_accuracy: 0.7864
# Epoch 46/80
# 30/30 [==============================] - 23s 753ms/step - loss: 0.5674 - accuracy: 0.7792 - val_loss: 0.6579 - val_accuracy: 0.7388
# Epoch 47/80
# 30/30 [==============================] - 22s 747ms/step - loss: 0.5574 - accuracy: 0.7836 - val_loss: 0.5693 - val_accuracy: 0.7837
# Epoch 48/80
# 30/30 [==============================] - 23s 754ms/step - loss: 0.5289 - accuracy: 0.7973 - val_loss: 0.5532 - val_accuracy: 0.7878
# Epoch 49/80
# 30/30 [==============================] - 22s 741ms/step - loss: 0.5477 - accuracy: 0.7806 - val_loss: 0.5495 - val_accuracy: 0.7796
# Epoch 50/80
# 30/30 [==============================] - 22s 747ms/step - loss: 0.5271 - accuracy: 0.7956 - val_loss: 0.5846 - val_accuracy: 0.7551
# Epoch 51/80
# 30/30 [==============================] - 23s 750ms/step - loss: 0.5156 - accuracy: 0.7990 - val_loss: 0.5693 - val_accuracy: 0.7782
# Epoch 52/80
# 30/30 [==============================] - 22s 737ms/step - loss: 0.5303 - accuracy: 0.7986 - val_loss: 0.5596 - val_accuracy: 0.7728
# Epoch 53/80
# 30/30 [==============================] - 22s 743ms/step - loss: 0.5115 - accuracy: 0.8048 - val_loss: 0.7379 - val_accuracy: 0.7388
# Epoch 54/80
# 30/30 [==============================] - 22s 744ms/step - loss: 0.5225 - accuracy: 0.7973 - val_loss: 0.5526 - val_accuracy: 0.7864
# Epoch 55/80
# 30/30 [==============================] - 23s 752ms/step - loss: 0.5191 - accuracy: 0.8020 - val_loss: 0.5170 - val_accuracy: 0.7810
# Epoch 56/80
# 30/30 [==============================] - 23s 762ms/step - loss: 0.4856 - accuracy: 0.8140 - val_loss: 0.6440 - val_accuracy: 0.7673
# Epoch 57/80
# 30/30 [==============================] - 23s 752ms/step - loss: 0.5328 - accuracy: 0.7857 - val_loss: 0.6248 - val_accuracy: 0.7578
# Epoch 58/80
# 30/30 [==============================] - 22s 747ms/step - loss: 0.5071 - accuracy: 0.8092 - val_loss: 0.5665 - val_accuracy: 0.7741
# Epoch 59/80
# 30/30 [==============================] - 22s 742ms/step - loss: 0.4933 - accuracy: 0.8017 - val_loss: 0.5911 - val_accuracy: 0.7810
# Epoch 60/80
# 30/30 [==============================] - 22s 739ms/step - loss: 0.4753 - accuracy: 0.8204 - val_loss: 0.5565 - val_accuracy: 0.7837
# Epoch 61/80
# 30/30 [==============================] - 23s 750ms/step - loss: 0.4861 - accuracy: 0.8194 - val_loss: 0.5807 - val_accuracy: 0.7728
# Epoch 62/80
# 30/30 [==============================] - 22s 750ms/step - loss: 0.4653 - accuracy: 0.8191 - val_loss: 0.6281 - val_accuracy: 0.7755
# Epoch 63/80
# 30/30 [==============================] - 22s 743ms/step - loss: 0.4372 - accuracy: 0.8317 - val_loss: 0.5166 - val_accuracy: 0.8000
# Epoch 64/80
# 30/30 [==============================] - 22s 735ms/step - loss: 0.4592 - accuracy: 0.8181 - val_loss: 0.5506 - val_accuracy: 0.8054
# Epoch 65/80
# 30/30 [==============================] - 22s 727ms/step - loss: 0.4854 - accuracy: 0.8102 - val_loss: 0.6208 - val_accuracy: 0.7755
# Epoch 66/80
# 30/30 [==============================] - 22s 724ms/step - loss: 0.4556 - accuracy: 0.8279 - val_loss: 0.6027 - val_accuracy: 0.7837
# Epoch 67/80
# 30/30 [==============================] - 22s 721ms/step - loss: 0.4527 - accuracy: 0.8252 - val_loss: 0.5840 - val_accuracy: 0.7782
# Epoch 68/80
# 30/30 [==============================] - 22s 724ms/step - loss: 0.4474 - accuracy: 0.8286 - val_loss: 0.5971 - val_accuracy: 0.7687
# Epoch 69/80
# 30/30 [==============================] - 22s 723ms/step - loss: 0.4605 - accuracy: 0.8218 - val_loss: 0.5724 - val_accuracy: 0.7796
# Epoch 70/80
# 30/30 [==============================] - 22s 727ms/step - loss: 0.4590 - accuracy: 0.8290 - val_loss: 0.5775 - val_accuracy: 0.7932
# Epoch 71/80
# 30/30 [==============================] - 22s 730ms/step - loss: 0.4245 - accuracy: 0.8429 - val_loss: 0.6080 - val_accuracy: 0.7878
# Epoch 72/80
# 30/30 [==============================] - 22s 725ms/step - loss: 0.4119 - accuracy: 0.8450 - val_loss: 0.5585 - val_accuracy: 0.7864
# Epoch 73/80
# 30/30 [==============================] - 22s 729ms/step - loss: 0.4300 - accuracy: 0.8382 - val_loss: 0.5443 - val_accuracy: 0.8027
# Epoch 74/80
# 30/30 [==============================] - 22s 737ms/step - loss: 0.4521 - accuracy: 0.8300 - val_loss: 0.5498 - val_accuracy: 0.8082
# Epoch 75/80
# 30/30 [==============================] - 22s 739ms/step - loss: 0.4111 - accuracy: 0.8467 - val_loss: 0.6026 - val_accuracy: 0.7823
# Epoch 76/80
# 30/30 [==============================] - 22s 742ms/step - loss: 0.4050 - accuracy: 0.8508 - val_loss: 0.5296 - val_accuracy: 0.7946
# Epoch 77/80
# 30/30 [==============================] - 22s 739ms/step - loss: 0.3922 - accuracy: 0.8484 - val_loss: 0.5677 - val_accuracy: 0.7864
# Epoch 78/80
# 30/30 [==============================] - 22s 745ms/step - loss: 0.4046 - accuracy: 0.8446 - val_loss: 0.5827 - val_accuracy: 0.8014
# Epoch 79/80
# 30/30 [==============================] - 22s 742ms/step - loss: 0.4042 - accuracy: 0.8463 - val_loss: 0.6200 - val_accuracy: 0.7905
# Epoch 80/80
# 30/30 [==============================] - 22s 738ms/step - loss: 0.4042 - accuracy: 0.8487 - val_loss: 0.6232 - val_accuracy: 0.7810

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
