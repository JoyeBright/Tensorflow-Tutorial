# %% [markdown]
# <a href="https://colab.research.google.com/github/JoyeBright/Tensorflow-Tutorial/blob/master/CatsDogs_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %% [markdown]
# ### **Download the Cats and Dogs Dataset**

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 1s 0us/step

# %%
import os

zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  
train_dogs_dir = os.path.join(train_dir, 'dogs')  
validation_cats_dir = os.path.join(validation_dir, 'cats')  
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# ## **Data Preparation**

# %%
BATCH_SIZE = 100 
IMG_SHAPE  = 150

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_image_generator      = ImageDataGenerator(rescale=1./255)
validation_image_generator = ImageDataGenerator(rescale=1./255)

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE),
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), 
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ## **Data Visualization**

# %%
sample_training_images, _ = next(train_data_gen)

# %%
import matplotlib.pyplot as plt

def plotImages(images_arr):
    fig, axes = plt.subplots(1, 6, figsize=(16,16))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
plotImages(sample_training_images[:6])

# %% [markdown]
# ## **Model Structure**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)), # the output shape will be (148, 148, 30) because of using padding='valid' which results in no zero padding 
    tf.keras.layers.MaxPooling2D(2, 2), # if stride equals None (which is by default), it will default to pool_size.

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### **Fitting**

# %%
import numpy as np
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

EPOCHS = 100

history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 9s 440ms/step - loss: 0.7308 - accuracy: 0.5050 - val_loss: 0.6900 - val_accuracy: 0.6130
# Epoch 2/100
# 20/20 [==============================] - 9s 436ms/step - loss: 0.6918 - accuracy: 0.5205 - val_loss: 0.6894 - val_accuracy: 0.5000
# Epoch 3/100
# 20/20 [==============================] - 9s 438ms/step - loss: 0.6932 - accuracy: 0.5330 - val_loss: 0.6892 - val_accuracy: 0.5300
# Epoch 4/100
# 20/20 [==============================] - 9s 432ms/step - loss: 0.6806 - accuracy: 0.5425 - val_loss: 0.6893 - val_accuracy: 0.5520
# Epoch 5/100
# 20/20 [==============================] - 9s 425ms/step - loss: 0.6440 - accuracy: 0.6140 - val_loss: 0.6392 - val_accuracy: 0.6390
# Epoch 6/100
# 20/20 [==============================] - 8s 423ms/step - loss: 0.6229 - accuracy: 0.6365 - val_loss: 0.6142 - val_accuracy: 0.6720
# Epoch 7/100
# 20/20 [==============================] - 8s 424ms/step - loss: 0.6094 - accuracy: 0.6480 - val_loss: 0.6388 - val_accuracy: 0.5920
# Epoch 8/100
# 20/20 [==============================] - 8s 422ms/step - loss: 0.5846 - accuracy: 0.6745 - val_loss: 0.6261 - val_accuracy: 0.6460
# Epoch 9/100
# 20/20 [==============================] - 8s 423ms/step - loss: 0.5265 - accuracy: 0.7295 - val_loss: 0.7019 - val_accuracy: 0.6370
# Epoch 10/100
# 20/20 [==============================] - 8s 418ms/step - loss: 0.5335 - accuracy: 0.7275 - val_loss: 0.6091 - val_accuracy: 0.6850
# Epoch 11/100
# 20/20 [==============================] - 8s 410ms/step - loss: 0.4575 - accuracy: 0.7825 - val_loss: 0.6536 - val_accuracy: 0.6670
# Epoch 12/100
# 20/20 [==============================] - 8s 415ms/step - loss: 0.4077 - accuracy: 0.8165 - val_loss: 0.6453 - val_accuracy: 0.6950
# Epoch 13/100
# 20/20 [==============================] - 8s 414ms/step - loss: 0.3693 - accuracy: 0.8370 - val_loss: 0.6478 - val_accuracy: 0.6920
# Epoch 14/100
# 20/20 [==============================] - 8s 412ms/step - loss: 0.2983 - accuracy: 0.8725 - val_loss: 0.7906 - val_accuracy: 0.7080
# Epoch 15/100
# 20/20 [==============================] - 8s 413ms/step - loss: 0.2665 - accuracy: 0.8975 - val_loss: 0.7492 - val_accuracy: 0.7270
# Epoch 16/100
# 20/20 [==============================] - 8s 414ms/step - loss: 0.2211 - accuracy: 0.9100 - val_loss: 0.7556 - val_accuracy: 0.6940
# Epoch 17/100
# 20/20 [==============================] - 8s 414ms/step - loss: 0.1522 - accuracy: 0.9370 - val_loss: 0.8989 - val_accuracy: 0.7210
# Epoch 18/100
# 20/20 [==============================] - 8s 418ms/step - loss: 0.0967 - accuracy: 0.9660 - val_loss: 1.0091 - val_accuracy: 0.7120
# Epoch 19/100
# 20/20 [==============================] - 8s 415ms/step - loss: 0.0649 - accuracy: 0.9785 - val_loss: 1.1722 - val_accuracy: 0.7160
# Epoch 20/100
# 20/20 [==============================] - 8s 407ms/step - loss: 0.0604 - accuracy: 0.9800 - val_loss: 1.1607 - val_accuracy: 0.7420
# Epoch 21/100
# 20/20 [==============================] - 8s 408ms/step - loss: 0.0472 - accuracy: 0.9830 - val_loss: 1.3768 - val_accuracy: 0.7230
# Epoch 22/100
# 20/20 [==============================] - 8s 410ms/step - loss: 0.0357 - accuracy: 0.9880 - val_loss: 1.2781 - val_accuracy: 0.7270
# Epoch 23/100
# 20/20 [==============================] - 8s 407ms/step - loss: 0.0147 - accuracy: 0.9980 - val_loss: 1.5133 - val_accuracy: 0.7280
# Epoch 24/100
# 20/20 [==============================] - 8s 408ms/step - loss: 0.0069 - accuracy: 0.9985 - val_loss: 1.6010 - val_accuracy: 0.7220
# Epoch 25/100
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.6761 - val_accuracy: 0.7190
# Epoch 26/100
# 20/20 [==============================] - 8s 407ms/step - loss: 9.9359e-04 - accuracy: 1.0000 - val_loss: 1.7751 - val_accuracy: 0.7260
# Epoch 27/100
# 20/20 [==============================] - 8s 404ms/step - loss: 6.0334e-04 - accuracy: 1.0000 - val_loss: 1.8533 - val_accuracy: 0.7260
# Epoch 28/100
# 20/20 [==============================] - 8s 406ms/step - loss: 4.2842e-04 - accuracy: 1.0000 - val_loss: 1.8978 - val_accuracy: 0.7300
# Epoch 29/100
# 20/20 [==============================] - 8s 408ms/step - loss: 3.3916e-04 - accuracy: 1.0000 - val_loss: 1.9373 - val_accuracy: 0.7290
# Epoch 30/100
# 20/20 [==============================] - 8s 407ms/step - loss: 2.8979e-04 - accuracy: 1.0000 - val_loss: 1.9779 - val_accuracy: 0.7300
# Epoch 31/100
# 20/20 [==============================] - 8s 405ms/step - loss: 2.4736e-04 - accuracy: 1.0000 - val_loss: 2.0122 - val_accuracy: 0.7290
# Epoch 32/100
# 20/20 [==============================] - 8s 402ms/step - loss: 2.1058e-04 - accuracy: 1.0000 - val_loss: 2.0414 - val_accuracy: 0.7300
# Epoch 33/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.8451e-04 - accuracy: 1.0000 - val_loss: 2.0688 - val_accuracy: 0.7320
# Epoch 34/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.6425e-04 - accuracy: 1.0000 - val_loss: 2.1008 - val_accuracy: 0.7310
# Epoch 35/100
# 20/20 [==============================] - 8s 403ms/step - loss: 1.4568e-04 - accuracy: 1.0000 - val_loss: 2.1221 - val_accuracy: 0.7300
# Epoch 36/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.3115e-04 - accuracy: 1.0000 - val_loss: 2.1437 - val_accuracy: 0.7320
# Epoch 37/100
# 20/20 [==============================] - 8s 402ms/step - loss: 1.1960e-04 - accuracy: 1.0000 - val_loss: 2.1728 - val_accuracy: 0.7300
# Epoch 38/100
# 20/20 [==============================] - 8s 406ms/step - loss: 1.0928e-04 - accuracy: 1.0000 - val_loss: 2.1870 - val_accuracy: 0.7330
# Epoch 39/100
# 20/20 [==============================] - 8s 412ms/step - loss: 9.9698e-05 - accuracy: 1.0000 - val_loss: 2.2130 - val_accuracy: 0.7310
# Epoch 40/100
# 20/20 [==============================] - 8s 409ms/step - loss: 9.1034e-05 - accuracy: 1.0000 - val_loss: 2.2313 - val_accuracy: 0.7310
# Epoch 41/100
# 20/20 [==============================] - 8s 400ms/step - loss: 8.3754e-05 - accuracy: 1.0000 - val_loss: 2.2562 - val_accuracy: 0.7290
# Epoch 42/100
# 20/20 [==============================] - 8s 395ms/step - loss: 7.7215e-05 - accuracy: 1.0000 - val_loss: 2.2693 - val_accuracy: 0.7290
# Epoch 43/100
# 20/20 [==============================] - 8s 393ms/step - loss: 6.9891e-05 - accuracy: 1.0000 - val_loss: 2.2972 - val_accuracy: 0.7270
# Epoch 44/100
# 20/20 [==============================] - 8s 395ms/step - loss: 6.4364e-05 - accuracy: 1.0000 - val_loss: 2.3262 - val_accuracy: 0.7260
# Epoch 45/100
# 20/20 [==============================] - 8s 403ms/step - loss: 5.8094e-05 - accuracy: 1.0000 - val_loss: 2.3399 - val_accuracy: 0.7310
# Epoch 46/100
# 20/20 [==============================] - 8s 402ms/step - loss: 5.1368e-05 - accuracy: 1.0000 - val_loss: 2.3945 - val_accuracy: 0.7290
# Epoch 47/100
# 20/20 [==============================] - 8s 406ms/step - loss: 4.5834e-05 - accuracy: 1.0000 - val_loss: 2.3811 - val_accuracy: 0.7290
# Epoch 48/100
# 20/20 [==============================] - 8s 406ms/step - loss: 3.9086e-05 - accuracy: 1.0000 - val_loss: 2.4324 - val_accuracy: 0.7280
# Epoch 49/100
# 20/20 [==============================] - 8s 399ms/step - loss: 3.4234e-05 - accuracy: 1.0000 - val_loss: 2.4420 - val_accuracy: 0.7300
# Epoch 50/100
# 20/20 [==============================] - 8s 398ms/step - loss: 3.1062e-05 - accuracy: 1.0000 - val_loss: 2.4625 - val_accuracy: 0.7320
# Epoch 51/100
# 20/20 [==============================] - 8s 398ms/step - loss: 2.6908e-05 - accuracy: 1.0000 - val_loss: 2.4784 - val_accuracy: 0.7320
# Epoch 52/100
# 20/20 [==============================] - 8s 397ms/step - loss: 2.4317e-05 - accuracy: 1.0000 - val_loss: 2.4933 - val_accuracy: 0.7310
# Epoch 53/100
# 20/20 [==============================] - 8s 395ms/step - loss: 2.1742e-05 - accuracy: 1.0000 - val_loss: 2.5153 - val_accuracy: 0.7320
# Epoch 54/100
# 20/20 [==============================] - 8s 391ms/step - loss: 1.9670e-05 - accuracy: 1.0000 - val_loss: 2.5268 - val_accuracy: 0.7290
# Epoch 55/100
# 20/20 [==============================] - 8s 395ms/step - loss: 1.8180e-05 - accuracy: 1.0000 - val_loss: 2.5360 - val_accuracy: 0.7340
# Epoch 56/100
# 20/20 [==============================] - 8s 396ms/step - loss: 1.6786e-05 - accuracy: 1.0000 - val_loss: 2.5465 - val_accuracy: 0.7330
# Epoch 57/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.5426e-05 - accuracy: 1.0000 - val_loss: 2.5585 - val_accuracy: 0.7310
# Epoch 58/100
# 20/20 [==============================] - 8s 399ms/step - loss: 1.4078e-05 - accuracy: 1.0000 - val_loss: 2.5706 - val_accuracy: 0.7310
# Epoch 59/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.3499e-05 - accuracy: 1.0000 - val_loss: 2.5815 - val_accuracy: 0.7300
# Epoch 60/100
# 20/20 [==============================] - 8s 396ms/step - loss: 1.3000e-05 - accuracy: 1.0000 - val_loss: 2.5752 - val_accuracy: 0.7280
# Epoch 61/100
# 20/20 [==============================] - 8s 399ms/step - loss: 1.3283e-05 - accuracy: 1.0000 - val_loss: 2.5736 - val_accuracy: 0.7320
# Epoch 62/100
# 20/20 [==============================] - 8s 398ms/step - loss: 1.2221e-05 - accuracy: 1.0000 - val_loss: 2.5831 - val_accuracy: 0.7330
# Epoch 63/100
# 20/20 [==============================] - 8s 398ms/step - loss: 1.0785e-05 - accuracy: 1.0000 - val_loss: 2.6207 - val_accuracy: 0.7360
# Epoch 64/100
# 20/20 [==============================] - 8s 396ms/step - loss: 1.1280e-05 - accuracy: 1.0000 - val_loss: 2.6081 - val_accuracy: 0.7330
# Epoch 65/100
# 20/20 [==============================] - 8s 399ms/step - loss: 9.6945e-06 - accuracy: 1.0000 - val_loss: 2.6207 - val_accuracy: 0.7300
# Epoch 66/100
# 20/20 [==============================] - 8s 398ms/step - loss: 9.0432e-06 - accuracy: 1.0000 - val_loss: 2.6320 - val_accuracy: 0.7330
# Epoch 67/100
# 20/20 [==============================] - 8s 404ms/step - loss: 8.4455e-06 - accuracy: 1.0000 - val_loss: 2.6352 - val_accuracy: 0.7320
# Epoch 68/100
# 20/20 [==============================] - 8s 399ms/step - loss: 8.0685e-06 - accuracy: 1.0000 - val_loss: 2.6364 - val_accuracy: 0.7310
# Epoch 69/100
# 20/20 [==============================] - 8s 395ms/step - loss: 7.4698e-06 - accuracy: 1.0000 - val_loss: 2.6506 - val_accuracy: 0.7300
# Epoch 70/100
# 20/20 [==============================] - 8s 395ms/step - loss: 7.0200e-06 - accuracy: 1.0000 - val_loss: 2.6598 - val_accuracy: 0.7300
# Epoch 71/100
# 20/20 [==============================] - 8s 393ms/step - loss: 6.8277e-06 - accuracy: 1.0000 - val_loss: 2.6595 - val_accuracy: 0.7290
# Epoch 72/100
# 20/20 [==============================] - 8s 396ms/step - loss: 6.5058e-06 - accuracy: 1.0000 - val_loss: 2.6704 - val_accuracy: 0.7280
# Epoch 73/100
# 20/20 [==============================] - 8s 395ms/step - loss: 6.1956e-06 - accuracy: 1.0000 - val_loss: 2.6767 - val_accuracy: 0.7280
# Epoch 74/100
# 20/20 [==============================] - 8s 395ms/step - loss: 5.9464e-06 - accuracy: 1.0000 - val_loss: 2.6798 - val_accuracy: 0.7300
# Epoch 75/100
# 20/20 [==============================] - 8s 396ms/step - loss: 5.6737e-06 - accuracy: 1.0000 - val_loss: 2.6942 - val_accuracy: 0.7300
# Epoch 76/100
# 20/20 [==============================] - 8s 402ms/step - loss: 5.3941e-06 - accuracy: 1.0000 - val_loss: 2.6969 - val_accuracy: 0.7290
# Epoch 77/100
# 20/20 [==============================] - 8s 406ms/step - loss: 5.2198e-06 - accuracy: 1.0000 - val_loss: 2.7011 - val_accuracy: 0.7300
# Epoch 78/100
# 20/20 [==============================] - 8s 395ms/step - loss: 5.1097e-06 - accuracy: 1.0000 - val_loss: 2.7071 - val_accuracy: 0.7290
# Epoch 79/100
# 20/20 [==============================] - 8s 395ms/step - loss: 5.0215e-06 - accuracy: 1.0000 - val_loss: 2.7146 - val_accuracy: 0.7280
# Epoch 80/100
# 20/20 [==============================] - 8s 390ms/step - loss: 4.9305e-06 - accuracy: 1.0000 - val_loss: 2.7192 - val_accuracy: 0.7310
# Epoch 81/100
# 20/20 [==============================] - 8s 390ms/step - loss: 4.5792e-06 - accuracy: 1.0000 - val_loss: 2.7251 - val_accuracy: 0.7310
# Epoch 82/100
# 20/20 [==============================] - 8s 389ms/step - loss: 4.3351e-06 - accuracy: 1.0000 - val_loss: 2.7329 - val_accuracy: 0.7320
# Epoch 83/100
# 20/20 [==============================] - 8s 388ms/step - loss: 4.1464e-06 - accuracy: 1.0000 - val_loss: 2.7370 - val_accuracy: 0.7310
# Epoch 84/100
# 20/20 [==============================] - 8s 389ms/step - loss: 4.0347e-06 - accuracy: 1.0000 - val_loss: 2.7423 - val_accuracy: 0.7320
# Epoch 85/100
# 20/20 [==============================] - 8s 391ms/step - loss: 3.9175e-06 - accuracy: 1.0000 - val_loss: 2.7446 - val_accuracy: 0.7310
# Epoch 86/100
# 20/20 [==============================] - 8s 391ms/step - loss: 3.8105e-06 - accuracy: 1.0000 - val_loss: 2.7617 - val_accuracy: 0.7300
# Epoch 87/100
# 20/20 [==============================] - 8s 397ms/step - loss: 3.7394e-06 - accuracy: 1.0000 - val_loss: 2.7547 - val_accuracy: 0.7290
# Epoch 88/100
# 20/20 [==============================] - 8s 401ms/step - loss: 3.5206e-06 - accuracy: 1.0000 - val_loss: 2.7637 - val_accuracy: 0.7300
# Epoch 89/100
# 20/20 [==============================] - 8s 398ms/step - loss: 3.4350e-06 - accuracy: 1.0000 - val_loss: 2.7706 - val_accuracy: 0.7290
# Epoch 90/100
# 20/20 [==============================] - 8s 423ms/step - loss: 3.3269e-06 - accuracy: 1.0000 - val_loss: 2.7771 - val_accuracy: 0.7300
# Epoch 91/100
# 20/20 [==============================] - 8s 393ms/step - loss: 3.3595e-06 - accuracy: 1.0000 - val_loss: 2.7799 - val_accuracy: 0.7320
# Epoch 92/100
# 20/20 [==============================] - 8s 392ms/step - loss: 3.3667e-06 - accuracy: 1.0000 - val_loss: 2.7752 - val_accuracy: 0.7310
# Epoch 93/100
# 20/20 [==============================] - 8s 394ms/step - loss: 3.0728e-06 - accuracy: 1.0000 - val_loss: 2.7854 - val_accuracy: 0.7290
# Epoch 94/100
# 20/20 [==============================] - 8s 392ms/step - loss: 2.9618e-06 - accuracy: 1.0000 - val_loss: 2.7910 - val_accuracy: 0.7290
# Epoch 95/100
# 20/20 [==============================] - 8s 395ms/step - loss: 2.8526e-06 - accuracy: 1.0000 - val_loss: 2.7967 - val_accuracy: 0.7280
# Epoch 96/100
# 20/20 [==============================] - 8s 397ms/step - loss: 2.8372e-06 - accuracy: 1.0000 - val_loss: 2.7972 - val_accuracy: 0.7300
# Epoch 97/100
# 20/20 [==============================] - 8s 396ms/step - loss: 2.7513e-06 - accuracy: 1.0000 - val_loss: 2.8054 - val_accuracy: 0.7280
# Epoch 98/100
# 20/20 [==============================] - 8s 394ms/step - loss: 2.7063e-06 - accuracy: 1.0000 - val_loss: 2.8048 - val_accuracy: 0.7280
# Epoch 99/100
# 20/20 [==============================] - 8s 395ms/step - loss: 2.5708e-06 - accuracy: 1.0000 - val_loss: 2.8118 - val_accuracy: 0.7290
# Epoch 100/100
# 20/20 [==============================] - 8s 393ms/step - loss: 2.5086e-06 - accuracy: 1.0000 - val_loss: 2.8180 - val_accuracy: 0.7290

# %% [markdown]
# ## **Plot Accuracy and Loss**
#
# *Based on training set and validation set*

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()
