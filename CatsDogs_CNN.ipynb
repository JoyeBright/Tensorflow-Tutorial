# %% [markdown]
# <a href="https://colab.research.google.com/github/JoyeBright/Tensorflow-Tutorial/blob/master/CatsDogs_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %% [markdown]
# ### **Download the Cats and Dogs Dataset**

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)

# %%
import os

zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats

# %%
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  
train_dogs_dir = os.path.join(train_dir, 'dogs')  
validation_cats_dir = os.path.join(validation_dir, 'cats')  
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('total training cat images:', num_cats_tr)
print('total training dog images:', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# ## **Data Preparation**

# %%
BATCH_SIZE = 100 
IMG_SHAPE  = 150

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_image_generator      = ImageDataGenerator(rescale=1./255)
validation_image_generator = ImageDataGenerator(rescale=1./255)

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE),
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), 
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ## **Data Visualization**

# %%
sample_training_images, _ = next(train_data_gen)

# %%
import matplotlib.pyplot as plt

def plotImages(images_arr):
    fig, axes = plt.subplots(1, 4, figsize=(16,16))
    axes = axes.flatten()
    for img, ax in zip(images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
plotImages(sample_training_images[:4])

# %% [markdown]
# ## **Model Structure**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)), # the output shape will be (148, 148, 30) because of using padding='valid' which results in no zero padding 
    tf.keras.layers.MaxPooling2D(2, 2), # if stride equals None (which is by default), it will default to pool_size.
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### **Fitting**

# %%
import numpy as np
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

EPOCHS = 100

history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(total_train / float(BATCH_SIZE))),
    epochs=EPOCHS,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(total_val / float(BATCH_SIZE)))
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.6851 - accuracy: 0.5505 - val_loss: 0.6632 - val_accuracy: 0.6420
# Epoch 2/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.6699 - accuracy: 0.5855 - val_loss: 0.6742 - val_accuracy: 0.6320
# Epoch 3/100
# 20/20 [==============================] - 8s 396ms/step - loss: 0.6269 - accuracy: 0.6605 - val_loss: 0.6066 - val_accuracy: 0.6680
# Epoch 4/100
# 20/20 [==============================] - 8s 401ms/step - loss: 0.5841 - accuracy: 0.6945 - val_loss: 0.6296 - val_accuracy: 0.6540
# Epoch 5/100
# 20/20 [==============================] - 8s 404ms/step - loss: 0.5801 - accuracy: 0.6855 - val_loss: 0.6055 - val_accuracy: 0.6730
# Epoch 6/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.5271 - accuracy: 0.7360 - val_loss: 0.5730 - val_accuracy: 0.7060
# Epoch 7/100
# 20/20 [==============================] - 8s 399ms/step - loss: 0.4711 - accuracy: 0.7760 - val_loss: 0.5491 - val_accuracy: 0.7200
# Epoch 8/100
# 20/20 [==============================] - 8s 396ms/step - loss: 0.4472 - accuracy: 0.7880 - val_loss: 0.5691 - val_accuracy: 0.7170
# Epoch 9/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.4244 - accuracy: 0.8120 - val_loss: 0.5613 - val_accuracy: 0.7030
# Epoch 10/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.3827 - accuracy: 0.8290 - val_loss: 0.5870 - val_accuracy: 0.7200
# Epoch 11/100
# 20/20 [==============================] - 8s 396ms/step - loss: 0.3657 - accuracy: 0.8330 - val_loss: 0.5716 - val_accuracy: 0.7300
# Epoch 12/100
# 20/20 [==============================] - 8s 397ms/step - loss: 0.3422 - accuracy: 0.8615 - val_loss: 0.5763 - val_accuracy: 0.7430
# Epoch 13/100
# 20/20 [==============================] - 8s 401ms/step - loss: 0.3071 - accuracy: 0.8655 - val_loss: 0.7131 - val_accuracy: 0.6990
# Epoch 14/100
# 20/20 [==============================] - 8s 402ms/step - loss: 0.2705 - accuracy: 0.8810 - val_loss: 0.5914 - val_accuracy: 0.7430
# Epoch 15/100
# 20/20 [==============================] - 8s 403ms/step - loss: 0.2181 - accuracy: 0.9065 - val_loss: 0.7160 - val_accuracy: 0.7280
# Epoch 16/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.2074 - accuracy: 0.9165 - val_loss: 0.6919 - val_accuracy: 0.7330
# Epoch 17/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.1568 - accuracy: 0.9420 - val_loss: 0.6558 - val_accuracy: 0.7710
# Epoch 18/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.1377 - accuracy: 0.9505 - val_loss: 0.7405 - val_accuracy: 0.7570
# Epoch 19/100
# 20/20 [==============================] - 8s 391ms/step - loss: 0.1285 - accuracy: 0.9530 - val_loss: 0.7618 - val_accuracy: 0.7580
# Epoch 20/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0874 - accuracy: 0.9720 - val_loss: 0.8836 - val_accuracy: 0.7550
# Epoch 21/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.0702 - accuracy: 0.9795 - val_loss: 0.9595 - val_accuracy: 0.7420
# Epoch 22/100
# 20/20 [==============================] - 8s 397ms/step - loss: 0.0490 - accuracy: 0.9885 - val_loss: 0.9040 - val_accuracy: 0.7540
# Epoch 23/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0308 - accuracy: 0.9940 - val_loss: 0.9972 - val_accuracy: 0.7560
# Epoch 24/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.0172 - accuracy: 0.9975 - val_loss: 1.0639 - val_accuracy: 0.7570
# Epoch 25/100
# 20/20 [==============================] - 8s 402ms/step - loss: 0.0157 - accuracy: 0.9965 - val_loss: 1.1228 - val_accuracy: 0.7570
# Epoch 26/100
# 20/20 [==============================] - 8s 399ms/step - loss: 0.0106 - accuracy: 0.9990 - val_loss: 1.1951 - val_accuracy: 0.7600
# Epoch 27/100
# 20/20 [==============================] - 8s 397ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 1.3447 - val_accuracy: 0.7480
# Epoch 28/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.3672 - val_accuracy: 0.7540
# Epoch 29/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.3932 - val_accuracy: 0.7490
# Epoch 30/100
# 20/20 [==============================] - 8s 392ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.4215 - val_accuracy: 0.7590
# Epoch 31/100
# 20/20 [==============================] - 8s 392ms/step - loss: 7.6142e-04 - accuracy: 1.0000 - val_loss: 1.4603 - val_accuracy: 0.7610
# Epoch 32/100
# 20/20 [==============================] - 8s 397ms/step - loss: 6.0856e-04 - accuracy: 1.0000 - val_loss: 1.4853 - val_accuracy: 0.7560
# Epoch 33/100
# 20/20 [==============================] - 8s 399ms/step - loss: 5.0937e-04 - accuracy: 1.0000 - val_loss: 1.5031 - val_accuracy: 0.7610
# Epoch 34/100
# 20/20 [==============================] - 8s 398ms/step - loss: 4.5260e-04 - accuracy: 1.0000 - val_loss: 1.5246 - val_accuracy: 0.7580
# Epoch 35/100
# 20/20 [==============================] - 8s 399ms/step - loss: 4.0590e-04 - accuracy: 1.0000 - val_loss: 1.5402 - val_accuracy: 0.7590
# Epoch 36/100
# 20/20 [==============================] - 8s 391ms/step - loss: 3.6292e-04 - accuracy: 1.0000 - val_loss: 1.5588 - val_accuracy: 0.7600
# Epoch 37/100
# 20/20 [==============================] - 8s 392ms/step - loss: 3.3598e-04 - accuracy: 1.0000 - val_loss: 1.5742 - val_accuracy: 0.7590
# Epoch 38/100
# 20/20 [==============================] - 8s 394ms/step - loss: 3.0642e-04 - accuracy: 1.0000 - val_loss: 1.5901 - val_accuracy: 0.7580
# Epoch 39/100
# 20/20 [==============================] - 8s 396ms/step - loss: 2.8085e-04 - accuracy: 1.0000 - val_loss: 1.6064 - val_accuracy: 0.7610
# Epoch 40/100
# 20/20 [==============================] - 8s 397ms/step - loss: 2.6246e-04 - accuracy: 1.0000 - val_loss: 1.6181 - val_accuracy: 0.7600
# Epoch 41/100
# 20/20 [==============================] - 8s 397ms/step - loss: 2.4319e-04 - accuracy: 1.0000 - val_loss: 1.6302 - val_accuracy: 0.7590
# Epoch 42/100
# 20/20 [==============================] - 8s 397ms/step - loss: 2.2479e-04 - accuracy: 1.0000 - val_loss: 1.6459 - val_accuracy: 0.7610
# Epoch 43/100
# 20/20 [==============================] - 8s 397ms/step - loss: 2.1073e-04 - accuracy: 1.0000 - val_loss: 1.6521 - val_accuracy: 0.7610
# Epoch 44/100
# 20/20 [==============================] - 8s 398ms/step - loss: 1.9798e-04 - accuracy: 1.0000 - val_loss: 1.6649 - val_accuracy: 0.7590
# Epoch 45/100
# 20/20 [==============================] - 8s 394ms/step - loss: 1.8559e-04 - accuracy: 1.0000 - val_loss: 1.6779 - val_accuracy: 0.7590
# Epoch 46/100
# 20/20 [==============================] - 8s 396ms/step - loss: 1.7398e-04 - accuracy: 1.0000 - val_loss: 1.6876 - val_accuracy: 0.7610
# Epoch 47/100
# 20/20 [==============================] - 8s 399ms/step - loss: 1.6416e-04 - accuracy: 1.0000 - val_loss: 1.7009 - val_accuracy: 0.7600
# Epoch 48/100
# 20/20 [==============================] - 8s 398ms/step - loss: 1.5420e-04 - accuracy: 1.0000 - val_loss: 1.7121 - val_accuracy: 0.7580
# Epoch 49/100
# 20/20 [==============================] - 8s 396ms/step - loss: 1.4575e-04 - accuracy: 1.0000 - val_loss: 1.7208 - val_accuracy: 0.7600
# Epoch 50/100
# 20/20 [==============================] - 8s 404ms/step - loss: 1.3827e-04 - accuracy: 1.0000 - val_loss: 1.7288 - val_accuracy: 0.7580
# Epoch 51/100
# 20/20 [==============================] - 8s 402ms/step - loss: 1.3091e-04 - accuracy: 1.0000 - val_loss: 1.7409 - val_accuracy: 0.7590
# Epoch 52/100
# 20/20 [==============================] - 8s 397ms/step - loss: 1.2526e-04 - accuracy: 1.0000 - val_loss: 1.7497 - val_accuracy: 0.7580
# Epoch 53/100
# 20/20 [==============================] - 8s 395ms/step - loss: 1.1906e-04 - accuracy: 1.0000 - val_loss: 1.7604 - val_accuracy: 0.7580
# Epoch 54/100
# 20/20 [==============================] - 8s 400ms/step - loss: 1.1371e-04 - accuracy: 1.0000 - val_loss: 1.7677 - val_accuracy: 0.7600
# Epoch 55/100
# 20/20 [==============================] - 8s 399ms/step - loss: 1.0848e-04 - accuracy: 1.0000 - val_loss: 1.7771 - val_accuracy: 0.7590
# Epoch 56/100
# 20/20 [==============================] - 8s 394ms/step - loss: 1.0315e-04 - accuracy: 1.0000 - val_loss: 1.7863 - val_accuracy: 0.7570
# Epoch 57/100
# 20/20 [==============================] - 8s 398ms/step - loss: 9.8220e-05 - accuracy: 1.0000 - val_loss: 1.7935 - val_accuracy: 0.7570
# Epoch 58/100
# 20/20 [==============================] - 8s 398ms/step - loss: 9.4637e-05 - accuracy: 1.0000 - val_loss: 1.8001 - val_accuracy: 0.7570
# Epoch 59/100
# 20/20 [==============================] - 8s 396ms/step - loss: 9.1005e-05 - accuracy: 1.0000 - val_loss: 1.8107 - val_accuracy: 0.7570
# Epoch 60/100
# 20/20 [==============================] - 8s 393ms/step - loss: 8.6882e-05 - accuracy: 1.0000 - val_loss: 1.8163 - val_accuracy: 0.7590
# Epoch 61/100
# 20/20 [==============================] - 8s 394ms/step - loss: 8.3291e-05 - accuracy: 1.0000 - val_loss: 1.8253 - val_accuracy: 0.7570
# Epoch 62/100
# 20/20 [==============================] - 8s 403ms/step - loss: 7.9860e-05 - accuracy: 1.0000 - val_loss: 1.8316 - val_accuracy: 0.7570
# Epoch 63/100
# 20/20 [==============================] - 8s 398ms/step - loss: 7.6683e-05 - accuracy: 1.0000 - val_loss: 1.8392 - val_accuracy: 0.7560
# Epoch 64/100
# 20/20 [==============================] - 8s 400ms/step - loss: 7.3995e-05 - accuracy: 1.0000 - val_loss: 1.8472 - val_accuracy: 0.7560
# Epoch 65/100
# 20/20 [==============================] - 8s 391ms/step - loss: 7.0936e-05 - accuracy: 1.0000 - val_loss: 1.8522 - val_accuracy: 0.7570
# Epoch 66/100
# 20/20 [==============================] - 8s 394ms/step - loss: 6.8382e-05 - accuracy: 1.0000 - val_loss: 1.8618 - val_accuracy: 0.7560
# Epoch 67/100
# 20/20 [==============================] - 8s 391ms/step - loss: 6.5576e-05 - accuracy: 1.0000 - val_loss: 1.8655 - val_accuracy: 0.7560
# Epoch 68/100
# 20/20 [==============================] - 8s 394ms/step - loss: 6.3674e-05 - accuracy: 1.0000 - val_loss: 1.8724 - val_accuracy: 0.7570
# Epoch 69/100
# 20/20 [==============================] - 8s 393ms/step - loss: 6.1167e-05 - accuracy: 1.0000 - val_loss: 1.8819 - val_accuracy: 0.7550
# Epoch 70/100
# 20/20 [==============================] - 8s 395ms/step - loss: 5.9038e-05 - accuracy: 1.0000 - val_loss: 1.8876 - val_accuracy: 0.7540
# Epoch 71/100
# 20/20 [==============================] - 8s 391ms/step - loss: 5.7001e-05 - accuracy: 1.0000 - val_loss: 1.8933 - val_accuracy: 0.7550
# Epoch 72/100
# 20/20 [==============================] - 8s 394ms/step - loss: 5.4935e-05 - accuracy: 1.0000 - val_loss: 1.8992 - val_accuracy: 0.7560
# Epoch 73/100
# 20/20 [==============================] - 8s 394ms/step - loss: 5.3319e-05 - accuracy: 1.0000 - val_loss: 1.9042 - val_accuracy: 0.7550
# Epoch 74/100
# 20/20 [==============================] - 8s 399ms/step - loss: 5.1535e-05 - accuracy: 1.0000 - val_loss: 1.9130 - val_accuracy: 0.7550
# Epoch 75/100
# 20/20 [==============================] - 8s 395ms/step - loss: 4.9862e-05 - accuracy: 1.0000 - val_loss: 1.9187 - val_accuracy: 0.7540
# Epoch 76/100
# 20/20 [==============================] - 8s 397ms/step - loss: 4.8052e-05 - accuracy: 1.0000 - val_loss: 1.9243 - val_accuracy: 0.7550
# Epoch 77/100
# 20/20 [==============================] - 8s 397ms/step - loss: 4.6539e-05 - accuracy: 1.0000 - val_loss: 1.9299 - val_accuracy: 0.7550
# Epoch 78/100
# 20/20 [==============================] - 8s 393ms/step - loss: 4.5093e-05 - accuracy: 1.0000 - val_loss: 1.9353 - val_accuracy: 0.7570
# Epoch 79/100
# 20/20 [==============================] - 8s 393ms/step - loss: 4.3832e-05 - accuracy: 1.0000 - val_loss: 1.9433 - val_accuracy: 0.7570
# Epoch 80/100
# 20/20 [==============================] - 8s 394ms/step - loss: 4.2414e-05 - accuracy: 1.0000 - val_loss: 1.9491 - val_accuracy: 0.7570
# Epoch 81/100
# 20/20 [==============================] - 8s 395ms/step - loss: 4.1295e-05 - accuracy: 1.0000 - val_loss: 1.9544 - val_accuracy: 0.7570
# Epoch 82/100
# 20/20 [==============================] - 8s 395ms/step - loss: 3.9804e-05 - accuracy: 1.0000 - val_loss: 1.9598 - val_accuracy: 0.7570
# Epoch 83/100
# 20/20 [==============================] - 8s 398ms/step - loss: 3.8770e-05 - accuracy: 1.0000 - val_loss: 1.9651 - val_accuracy: 0.7570
# Epoch 84/100
# 20/20 [==============================] - 8s 400ms/step - loss: 3.7537e-05 - accuracy: 1.0000 - val_loss: 1.9712 - val_accuracy: 0.7570
# Epoch 85/100
# 20/20 [==============================] - 8s 402ms/step - loss: 3.6611e-05 - accuracy: 1.0000 - val_loss: 1.9770 - val_accuracy: 0.7570
# Epoch 86/100
# 20/20 [==============================] - 8s 397ms/step - loss: 3.5715e-05 - accuracy: 1.0000 - val_loss: 1.9806 - val_accuracy: 0.7560
# Epoch 87/100
# 20/20 [==============================] - 8s 398ms/step - loss: 3.4750e-05 - accuracy: 1.0000 - val_loss: 1.9889 - val_accuracy: 0.7560
# Epoch 88/100
# 20/20 [==============================] - 8s 407ms/step - loss: 3.3527e-05 - accuracy: 1.0000 - val_loss: 1.9935 - val_accuracy: 0.7560
# Epoch 89/100
# 20/20 [==============================] - 8s 397ms/step - loss: 3.2614e-05 - accuracy: 1.0000 - val_loss: 1.9986 - val_accuracy: 0.7560
# Epoch 90/100
# 20/20 [==============================] - 8s 394ms/step - loss: 3.1684e-05 - accuracy: 1.0000 - val_loss: 2.0033 - val_accuracy: 0.7560
# Epoch 91/100
# 20/20 [==============================] - 8s 398ms/step - loss: 3.0885e-05 - accuracy: 1.0000 - val_loss: 2.0085 - val_accuracy: 0.7560
# Epoch 92/100
# 20/20 [==============================] - 8s 396ms/step - loss: 2.9995e-05 - accuracy: 1.0000 - val_loss: 2.0136 - val_accuracy: 0.7550
# Epoch 93/100
# 20/20 [==============================] - 8s 397ms/step - loss: 2.9292e-05 - accuracy: 1.0000 - val_loss: 2.0186 - val_accuracy: 0.7560
# Epoch 94/100
# 20/20 [==============================] - 8s 395ms/step - loss: 2.8431e-05 - accuracy: 1.0000 - val_loss: 2.0251 - val_accuracy: 0.7560
# Epoch 95/100
# 20/20 [==============================] - 8s 393ms/step - loss: 2.7709e-05 - accuracy: 1.0000 - val_loss: 2.0290 - val_accuracy: 0.7560
# Epoch 96/100
# 20/20 [==============================] - 8s 394ms/step - loss: 2.6924e-05 - accuracy: 1.0000 - val_loss: 2.0335 - val_accuracy: 0.7560
# Epoch 97/100
# 20/20 [==============================] - 8s 391ms/step - loss: 2.6221e-05 - accuracy: 1.0000 - val_loss: 2.0388 - val_accuracy: 0.7570
# Epoch 98/100
# 20/20 [==============================] - 8s 391ms/step - loss: 2.5630e-05 - accuracy: 1.0000 - val_loss: 2.0430 - val_accuracy: 0.7570
# Epoch 99/100
# 20/20 [==============================] - 8s 400ms/step - loss: 2.4984e-05 - accuracy: 1.0000 - val_loss: 2.0486 - val_accuracy: 0.7550
# Epoch 100/100
# 20/20 [==============================] - 8s 391ms/step - loss: 2.4321e-05 - accuracy: 1.0000 - val_loss: 2.0525 - val_accuracy: 0.7560

# %% [markdown]
# ## **Plot Accuracy and Loss**
#
# *Based on training set and validation set*

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()
